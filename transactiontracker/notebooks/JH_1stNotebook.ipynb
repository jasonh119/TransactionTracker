# %%
import sys
import datetime

# Current time using datetime module
#print("Current datetime:", datetime.datetime.now())
#print("Current date:", datetime.date.today())

# Formatted timestamps for logging
#print("Formatted for logs:", datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
#print("ISO format:", datetime.datetime.now().isoformat())

print(datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"), ":", sys.version)

thisList = ["apple", "kiwi", "mango"]
# Out:
# Formatted for logs: 2025-08-22 23:42:56
# ISO format: 2025-08-22T23:42:56.259885
# 2025-08-22 23:42:56 : 3.13.0 (tags/v3.13.0:60403a5, Oct  7 2024, 09:38:07) [MSC v.1941 64 bit (AMD64)]

# %%
print ("hello")

thisList = ["apple", "kiwi", "mango"]
print(thisList)
# Out:
# hello
# ['apple', 'kiwi', 'mango']

# %%
import requests

url = "https://pokeapi.co/api/v2/berry/cheri"
#params = {""}

response = requests.get(url)
print(response)

if response.status_code == 200:
    data = response.json()
    print (data)
# Out:
# <Response [200]>
# {'firmness': {'name': 'soft', 'url': 'https://pokeapi.co/api/v2/berry-firmness/2/'}, 'flavors': [{'flavor': {'name': 'spicy', 'url': 'https://pokeapi.co/api/v2/berry-flavor/1/'}, 'potency': 10}, {'flavor': {'name': 'dry', 'url': 'https://pokeapi.co/api/v2/berry-flavor/2/'}, 'potency': 0}, {'flavor': {'name': 'sweet', 'url': 'https://pokeapi.co/api/v2/berry-flavor/3/'}, 'potency': 0}, {'flavor': {'name': 'bitter', 'url': 'https://pokeapi.co/api/v2/berry-flavor/4/'}, 'potency': 0}, {'flavor': {'name': 'sour', 'url': 'https://pokeapi.co/api/v2/berry-flavor/5/'}, 'potency': 0}], 'growth_time': 3, 'id': 1, 'item': {'name': 'cheri-berry', 'url': 'https://pokeapi.co/api/v2/item/126/'}, 'max_harvest': 5, 'name': 'cheri', 'natural_gift_power': 60, 'natural_gift_type': {'name': 'fire', 'url': 'https://pokeapi.co/api/v2/type/10/'}, 'size': 20, 'smoothness': 25, 'soil_dryness': 15}

# %%
import requests

url = "https://pokeapi.co/api/v2/berry"
params = {"name": "cheri"}

response = requests.get(url, params)
print (response)
print (params)

if response.status_code == 200:
    data = response.json()
    print (data)
# Out:
# <Response [200]>
# {'name': 'cheri'}
# ...

# %%
import requests

params = {'name': 'limber'}
url = f"https://pokeapi.co/api/v2/pokemon/ditto"

response = requests.get(url, params)

if response.status_code == 200:
    data = response.json()
    print (data)
    
else:
    print(f"Error: {response.status_code}")
# Out:
# {'abilities': [{'ability': {'name': 'limber', 'url': 'https://pokeapi.co/api/v2/ability/7/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'imposter', 'url': 'https://pokeapi.co/api/v2/ability/150/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 101, 'cries': {'latest': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/132.ogg', 'legacy': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/132.ogg'}, 'forms': [{'name': 'ditto', 'url': 'https://pokeapi.co/api/v2/pokemon-form/132/'}], 'game_indices': [{'game_index': 76, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 76, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 76, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 132, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 132, 'version': {'name': 'silv
# ...
